# %%
# Import all modules
from databases.retrieval import main  # Retrieve sales data
from analysis.processing import (
    resample_weekly_sales,
)  # Process sales data into weekly summary
from analysis.plots import (
    plot_weekly_trends,
    plot_100_stacked_bar,
)  # Plot sales into weekly trends

# Import all libraries
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
from datetime import datetime, timedelta

# Ignore warnings, set seaborn to prettify charts
warnings.filterwarnings("ignore")
sns.set()

# Take in data
sales_df = main("deep-diver", "boreport", "Probability 90% Date")

# %% [markdown]
# # Sales Reporting

# %%
# Get weekly sales data from last week
weekly_sales = resample_weekly_sales(sales_df, "2024")
weekly_sales.tail(10)
# Out:
#  Channel              ONLINE  INSIDE SALES
# Probability 90% Date
# 2024-08-25             339.0         161.0
# 2024-09-01             306.0         163.0
# 2024-09-08             388.0         154.0
# 2024-09-15             326.0          91.0
# 2024-09-22             252.0         110.0
# 2024-09-29             349.0         142.0
# 2024-10-06             435.0         187.0
# 2024-10-13             409.0         205.0
# 2024-10-20             322.0         176.0
# 2024-10-27             318.0         154.0

# %%
# Get quick summary statistics of data
weekly_sales.describe()
# Out:
#  Channel      ONLINE  INSIDE SALES
# count      43.000000     43.000000
# mean      343.883721    116.627907
# std        53.074166     47.145683
# min       238.000000     35.000000
# 25%       305.500000     79.500000
# 50%       339.000000    127.000000
# 75%       384.500000    148.000000
# max       455.000000    206.000000

# %%
plot_weekly_trends(weekly_sales)

# %%
plot_100_stacked_bar(weekly_sales, datetime(2024, 1, 7))
