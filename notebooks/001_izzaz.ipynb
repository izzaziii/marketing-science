# %%
# Check sales

import pandas as pd
from databases.retrieval import retrieve_data_as_dataframe, convert_column_to_datetime
from datasets.boreport import resample_weekly_boreport, prepare_sales_data_direct_channels

# %%
df = retrieve_data_as_dataframe("boreport", "deep-diver")
df = convert_column_to_datetime(df, "Probability 90% Date")

# %%
df = prepare_sales_data_direct_channels(df)

# %%
df = df.dropna(subset="Probability 90% Date")
df_channel, df_bandwidth, df_state, df_contract = resample_weekly_boreport(df)

# %%
import matplotlib.pyplot as plt
df_channel.plot(
    kind='line',
    figsize=(15,6)
)
# Out:
# <Axes: xlabel='Probability 90% Date'>
